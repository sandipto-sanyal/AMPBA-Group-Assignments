# %%
import pandas as pd
import os

# %%
path = '/home/ec2-user/SageMaker/kaggle-carbon-monoxide-data'
file = 'epa_co_daily_summary.csv'

# %%
df = pd.read_csv(os.path.join(path,file),nrows=20000)

# %%
df.head()
# Out:
#    state_code  county_code  site_num  parameter_code  poc   latitude  \
# 0           6           73         5           42101    1  33.202650
# 1          39          113        28           42101    1  39.787222
# 2          30           31        16           42101    1  44.661393
# 3          51           13        20           42101    1  38.857700
# 4           6           65      8001           42101    1  33.999580
#
#     longitude  datum   parameter_name sample_duration  ... aqi method_code  \
# 0 -117.365925  NAD27  Carbon monoxide          1 HOUR  ... NaN        66.0
# 1  -84.226111  NAD83  Carbon monoxide          1 HOUR  ... NaN        67.0
# 2 -111.105891  WGS84  Carbon monoxide          1 HOUR  ... NaN        93.0
# 3  -77.059220  WGS84  Carbon monoxide          1 HOUR  ... NaN        67.0
# 4 -117.416010  WGS84  Carbon monoxide          1 HOUR  ... NaN        67.0
#
#                                          method_name  \
# ...

# %%
df.columns
# Out:
# Index(['state_code', 'county_code', 'site_num', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter_name', 'sample_duration',
#        'pollutant_standard', 'date_local', 'units_of_measure', 'event_type',
#        'observation_count', 'observation_percent', 'arithmetic_mean',
#        'first_max_value', 'first_max_hour', 'aqi', 'method_code',
#        'method_name', 'local_site_name', 'address', 'state_name',
#        'county_name', 'city_name', 'cbsa_name', 'date_of_last_change'],
#       dtype='object')

# %%
df.parameter_name.unique()
# Out:
# array(['Carbon monoxide'], dtype=object)
