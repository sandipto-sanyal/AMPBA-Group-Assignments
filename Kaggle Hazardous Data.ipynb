# %%
import pandas as pd
import os

# %%
path = '/home/ec2-user/SageMaker/kaggle-hazardous/epa_hap_daily_summary.csv'

# %%
df = pd.read_csv(os.path.join(path),nrows=20000)

# %%
df.head()
# Out:
#    state_code  county_code  site_num  parameter_code  poc   latitude  \
# 0          42          125      5001           88103    5  40.445278
# 1          48          439      1002           43843   15  32.805818
# 2          22          127      9000           88128    1  32.057581
# 3          18           89        22           45201    1  41.606680
# 4           6           89      3003           88136    1  40.539990
#
#     longitude  datum      parameter_name sample_duration  ...  aqi  \
# 0  -80.420833  WGS84    Arsenic PM2.5 LC         24 HOUR  ...  NaN
# 1  -97.356568  WGS84  Ethylene dibromide         24 HOUR  ...  NaN
# 2  -92.435157  WGS84       Lead PM2.5 LC         24 HOUR  ...  NaN
# 3  -87.304729  WGS84             Benzene          1 HOUR  ...  NaN
# 4 -121.576460  NAD83     Nickel PM2.5 LC         24 HOUR  ...  NaN
#
#   method_code                                        method_name  \
# 0         811         Met OneSASS Teflon - Energy dispersive XRF
# ...

# %%
df.parameter_name.unique()
# Out:
# array(['Arsenic PM2.5 LC', 'Ethylene dibromide', 'Lead PM2.5 LC',
#        'Benzene', 'Nickel PM2.5 LC', 'Lead PM10 STP',
#        'Acrolein - Unverified', 'Chromium (TSP) STP',
#        'cis-13-Dichloropropene', 'Manganese PM2.5 LC',
#        'Trichloroethylene', 'Tetrachloroethylene', '13-Butadiene',
#        'Chromium PM2.5 LC', 'Chloroform', 'Carbon tetrachloride',
#        'Cadmium PM2.5 LC', '1122-Tetrachloroethane',
#        'Manganese (TSP) STP', 'trans-13-Dichloropropene',
#        'Cadmium PM10 STP', 'Vinyl chloride', '12-Dichloropropane',
#        'Arsenic (TSP) STP', 'Dichloromethane', 'Nickel PM10 STP',
#        'Formaldehyde', 'Cadmium (TSP) STP', 'Manganese PM10 STP',
#        'Ethylene dichloride', 'Acetaldehyde', 'Beryllium PM10 STP',
#        'Beryllium (TSP) STP', 'Acrolein - Verified', 'Nickel (TSP) STP',
#        'Arsenic PM10 STP', 'Chromium PM10 STP', 'Chromium VI (TSP) STP',
#        'Mercury PM10 STP', 'Chromium VI (TSP) LC', 'Beryllium PM2.5 LC'],
# ...
